# %%
import pickle
import seaborn as sns
import pandas as pd

# %%
with open('classreport.txt', 'rb') as f:
     dic = pickle.load(f)
print(dic['c'])
# Out:
# [[47  0  0  2]
#  [ 0 56  0  0]
#  [ 7  0 44  0]
#  [ 0  0  0 44]]

# %%
CL = ['Bicep Curl', 'Overhead Press', 'Shoulder Raise', 'Squats']

# %%
cm_array_df = pd.DataFrame(dic['c'], index=CL, columns=CL)

# %%
sns.heatmap(cm_array_df, cmap='crest',annot=True)
# Out:
# <AxesSubplot:>
